# %%
import os
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
from dotenv import load_dotenv

import src.features.basic as ftr_basic
import src.features.transforms as transforms
import src.features.transforms as trf
import src.utils.io as io_utils

# %%
load_dotenv()
warnings.filterwarnings("ignore")
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2


ROOT = Path(os.getenv("ROOT"))
CONFIG_DIR = ROOT / Path("src/config/")
DATA_CFG = io_utils.load_yaml(CONFIG_DIR / "data.yaml")

RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)

# %%
DATA_PATH = DATA_CFG["data_raw"]["test_path"]
data = pd.read_csv(ROOT / DATA_PATH)

data.head()
# Out:
#        id  age            job  marital  education default  balance housing  \
# 0  750000   32    blue-collar  married  secondary      no     1397     yes
# 1  750001   44     management  married   tertiary      no       23     yes
# 2  750002   36  self-employed  married    primary      no       46     yes
# 3  750003   58    blue-collar  married  secondary      no    -1380     yes
# 4  750004   28     technician   single  secondary      no     1950     yes
#
#   loan   contact  day month  duration  campaign  pdays  previous poutcome
# 0   no   unknown   21   may       224         1     -1         0  unknown
# 1   no  cellular    3   apr       586         2     -1         0  unknown
# 2  yes  cellular   13   may       111         2     -1         0  unknown
# 3  yes   unknown   29   may       125         1     -1         0  unknown
# 4   no  cellular   22   jul       181         1     -1         0  unknown

# %%
data_ids = data["id"]
data = data.drop(columns=["id"])

data.head()
# Out:
#    age            job  marital  education default  balance housing loan  \
# 0   32    blue-collar  married  secondary      no     1397     yes   no
# 1   44     management  married   tertiary      no       23     yes   no
# 2   36  self-employed  married    primary      no       46     yes  yes
# 3   58    blue-collar  married  secondary      no    -1380     yes  yes
# 4   28     technician   single  secondary      no     1950     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome
# 0   unknown   21   may       224         1     -1         0  unknown
# 1  cellular    3   apr       586         2     -1         0  unknown
# 2  cellular   13   may       111         2     -1         0  unknown
# 3   unknown   29   may       125         1     -1         0  unknown
# 4  cellular   22   jul       181         1     -1         0  unknown

# %%
data.isna().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# dtype: int64

# %%
def transforms(df: pd.DataFrame) -> pd.DataFrame:
    trans = {
        "was_contact": trf.was_contact(df),
        "credit_score": trf.credit_score(df),
        "job_marital": trf.job_marital(df),
        "job_education": trf.job_education(df),
        "education_marital": trf.education_marital(df),
        "campaign_cat": trf.campaign_categorical(df),
        "pdays_cat": trf.pdays_categorical(df),
        "previous_cat": trf.previous_categorical(df),
        "log_duration": trf.log_duration(df),
        "log_balance": trf.log_balance(df),
        "multiply_logs": trf.multiply_logs(df),
        "is_overdraft": trf.is_overdraft(df),
        "sin_month": trf.sin_month(df),
        "cos_month": trf.cos_month(df),
        "sin_day": trf.sin_day(df),
        "cos_day": trf.cos_day(df),
    }
    df_new = df.copy()
    for col in trans:
        df_new[col] = trans[col]
    return df_new

# %%
data_new = transforms(data)

data_new.head()
# Out:
#    age            job  marital  education default  balance housing loan  \
# 0   32    blue-collar  married  secondary      no     1397     yes   no
# 1   44     management  married   tertiary      no       23     yes   no
# 2   36  self-employed  married    primary      no       46     yes  yes
# 3   58    blue-collar  married  secondary      no    -1380     yes  yes
# 4   28     technician   single  secondary      no     1950     yes   no
#
#     contact  day  ...   pdays_cat  previous_cat  log_duration  log_balance  \
# 0   unknown   21  ...  no_contact             0      5.416100     7.242798
# 1  cellular    3  ...  no_contact             0      6.375025     3.178054
# 2  cellular   13  ...  no_contact             0      4.718499     3.850148
# 3   unknown   29  ...  no_contact             0      4.836282     0.000000
# 4  cellular   22  ...  no_contact             0      5.204007     7.576097
#
#    multiply_logs is_overdraft     sin_month     cos_month   sin_day   cos_day
# 0      39.227721            0  8.660254e-01 -5.000000e-01 -0.790776 -0.612106
# 1      20.260172            0  1.000000e+00  6.123234e-17  0.394356  0.918958
# 2      18.166917            0  8.660254e-01 -5.000000e-01  0.651372 -0.758758
# 3       0.000000            1  8.660254e-01 -5.000000e-01 -0.571268  0.820763
# 4      39.426061            0  1.224647e-16 -1.000000e+00 -0.897805 -0.440394
#
# [5 rows x 32 columns]

# %%
jbm_enc = trf.JobBalanceEnc()
data_new["jb_mean"] = jbm_enc.fit_transform(data_new)

# %%
drop_columns = [
    "default",
    "balance",
    "housing",
    "loan",
    "day",
    "month",
    "duration",
    "campaign",
    "pdays",
    "previous",
]

# %%
data_new = data_new.drop(columns=drop_columns)

data_new.head()
# Out:
#    age            job  marital  education   contact poutcome  was_contact  \
# 0   32    blue-collar  married  secondary   unknown  unknown            0
# 1   44     management  married   tertiary  cellular  unknown            0
# 2   36  self-employed  married    primary  cellular  unknown            0
# 3   58    blue-collar  married  secondary   unknown  unknown            0
# 4   28     technician   single  secondary  cellular  unknown            0
#
#    credit_score            job_marital          job_education  ...  \
# 0             1    blue-collar_married  blue-collar_secondary  ...
# 1             1     management_married    management_tertiary  ...
# 2             2  self-employed_married  self-employed_primary  ...
# 3             2    blue-collar_married  blue-collar_secondary  ...
# 4             1      technician_single   technician_secondary  ...
#
#   previous_cat log_duration log_balance multiply_logs  is_overdraft  \
# 0            0     5.416100    7.242798     39.227721             0
# 1            0     6.375025    3.178054     20.260172             0
# 2            0     4.718499    3.850148     18.166917             0
# 3            0     4.836282    0.000000      0.000000             1
# 4            0     5.204007    7.576097     39.426061             0
#
#       sin_month     cos_month   sin_day   cos_day      jb_mean
# 0  8.660254e-01 -5.000000e-01 -0.790776 -0.612106   958.583490
# 1  1.000000e+00  6.123234e-17  0.394356  0.918958  1519.520961
# 2  8.660254e-01 -5.000000e-01  0.651372 -0.758758  1539.786643
# 3  8.660254e-01 -5.000000e-01 -0.571268  0.820763   958.583490
# 4  1.224647e-16 -1.000000e+00 -0.897805 -0.440394  1075.092114
#
# [5 rows x 23 columns]

# %%
ftr_names = ftr_basic.get_features_names(data_new)
cat_features, num_features = ftr_names["categorical"], ftr_names["numeric"]

data_new = ftr_basic.cat_features_to_category(data_new)

# %%
io_utils.save_df_parquet(data_new, ROOT / "data/processed/test_new_features.parquet")
io_utils.save_df_parquet(data_ids, ROOT / "data/processed/test_ids.parquet")
